# %% [markdown]
# ## Installation of packages using conda
# #### First please set up a new conda environment using https://datalab-docs.datalabs.ceh.ac.uk/tutorials/getting-started-jupyter/create-conda-environment.html and then run these package installations

# %%
conda update --name base conda
# Out:
# Channels:
#  - conda-forge
#  - pyviz
#  - plotly
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-2.128                 |         openblas          16 KB  conda-forge
#     blas-devel-3.9.0           |28_h1ea3ea9_openblas          16 KB  conda-forge
#     certifi-2024.12.14         |     pyhd8ed1ab_0         158 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     liblapacke-3.9.0           |28_he2f377e_openblas          16 KB  conda-forge
#     libopenblas-0.3.28         |pthreads_h94d23a6_0         5.3 MB  conda-forge
#     openblas-0.3.28            |pthreads_h6ec200e_0         5.5 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
conda update --all
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /data/conda/s3fs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     dask-2024.8.0              |     pyhd8ed1ab_0           7 KB  conda-forge
#     dask-core-2024.8.0         |     pyhd8ed1ab_0         860 KB  conda-forge
#     dask-expr-1.1.10           |     pyhd8ed1ab_0         181 KB  conda-forge
#     distributed-2024.8.0       |     pyhd8ed1ab_0         781 KB  conda-forge
#     kernel-headers_linux-64-5.14.0|       h8bc681e_0         1.3 MB  conda-forge
#     sysroot_linux-64-2.34      |       h8bc681e_0        39.2 MB  conda-forge
# ...

# %%
conda install --prefix /data/conda/s3fs -c conda-forge xarray matplotlib flox plotly boto3 pandas nbformat ipywidgets dask distributed s3fs tini lz4 zarr folium cf-python cf-plot udunits2
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /data/conda/s3fs
#
#   added / updated specs:
#     - cf-plot
#     - cf-python
#     - dask
#     - distributed
#     - folium
#     - ipywidgets
#     - lz4
#     - matplotlib
#     - nbformat
#     - pandas
#     - plotly
#     - s3fs
#     - tini
#     - udunits2
#     - zarr
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.19.0         |     pyhd8ed1ab_0          66 KB  conda-forge
#     aiohappyeyeballs-2.4.4     |     pyhd8ed1ab_1          19 KB  conda-forge
# ...
